# %%
print("hello")
# Out:
# hello

# %%
from deepaudiox.backbones.beats.beatswrapper import BEATsBackbone

# %%
model = BEATsBackbone(preprocess_flag=True, div_encoder_layer=True)
# Out:
# /Users/chrisnick/projects/deepaudio-x/.venv/lib/python3.13/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)

# %%
import torch
x = torch.randn(4, 16000)  # Example input tensor with batch size 2 and length 16000
output = model(x)

# %%
output.shape
# Out:
# torch.Size([4, 128])

# %%
model.load_state_dict(torch.load("BEATS_transfer_normalize.pt", map_location="cpu"))
# Out:
# <All keys matched successfully>
